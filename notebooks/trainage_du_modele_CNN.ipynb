# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install opencv-python

# %%
! pip install tensorflow

# %%
! pip install keras

# %%
import numpy as np
import cv2
import tensorflow
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd
from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import imutils
import dlib
import shutil, sys, os, dlib, glob, cv2

# %%
from scipy.spatial import distance as dist
from imutils import face_utils
from threading import Thread
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time
import os
import dlib
from google.colab.patches import cv2_imshow
from skimage import io

# %%
time.sleep(2)
from google.colab import output

# %%
data = np.load('/content/drive/MyDrive/new_pfe/driver_drowsiness_detection/dataset_compressed.npz', allow_pickle=True)
X = data['arr_0']
Y = data['arr_1']
X = list(X)
Y = list(Y)
print(len(X))
print(len(Y))

# %%
print(data.files)

# %%
for i in range(len(X)):
    img = X[i]
    img = cv2.resize(img, (32, 32))
    X[i] = img
    
print(len(X))
print(X[0].shape)

# %%
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
print(Y.shape)
print(Y[0])
print(set(Y))

# %%
X = np.array(X)
Y = np.array(Y)
print(X.shape)
print(Y.shape)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)

# %%
def driver_drowsiness_detection_model(input_shape=(32, 32, 3)):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv5', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv6', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv7', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    
    optimizer = Adam(0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= driver_drowsiness_detection_model(input_shape=(32, 32, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 8, 8, 64)          36928
#
#  batch_normalization_3 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv5 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_4 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  conv6 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_5 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  conv7 (Conv2D)              (None, 4, 4, 64)          36928
#
#  batch_normalization_6 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 4, 4, 64)          0
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  fc1 (Dense)                 (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  fc2 (Dense)                 (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  fc3 (Dense)                 (None, 2)                 258
#
# =================================================================
# Total params: 227,554
# Trainable params: 226,786
# Non-trainable params: 768
# _________________________________________________________________

# %%
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.2, horizontal_flip=True)
hist = model.fit(aug.flow(X_train, Y_train, batch_size=128), batch_size=128, epochs=200, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# 10/10 [==============================] - 9s 866ms/step - loss: 0.0401 - accuracy: 0.9871 - val_loss: 0.0191 - val_accuracy: 0.9931
# Epoch 2/200
# 10/10 [==============================] - 13s 1s/step - loss: 0.0376 - accuracy: 0.9828 - val_loss: 0.0153 - val_accuracy: 0.9966
# Epoch 3/200
# 10/10 [==============================] - 14s 1s/step - loss: 0.0392 - accuracy: 0.9854 - val_loss: 0.0159 - val_accuracy: 0.9931
# Epoch 4/200
# 10/10 [==============================] - 11s 1s/step - loss: 0.0444 - accuracy: 0.9879 - val_loss: 0.0198 - val_accuracy: 0.9931
# Epoch 5/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0204 - accuracy: 0.9931 - val_loss: 0.0195 - val_accuracy: 0.9931
# Epoch 6/200
# 10/10 [==============================] - 8s 745ms/step - loss: 0.0306 - accuracy: 0.9897 - val_loss: 0.0220 - val_accuracy: 0.9931
# Epoch 7/200
# 10/10 [==============================] - 7s 734ms/step - loss: 0.0420 - accuracy: 0.9871 - val_loss: 0.0222 - val_accuracy: 0.9931
# Epoch 8/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0310 - accuracy: 0.9888 - val_loss: 0.0211 - val_accuracy: 0.9931
# Epoch 9/200
# 10/10 [==============================] - 8s 739ms/step - loss: 0.0493 - accuracy: 0.9854 - val_loss: 0.0245 - val_accuracy: 0.9931
# Epoch 10/200
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0348 - accuracy: 0.9845 - val_loss: 0.0263 - val_accuracy: 0.9931
# Epoch 11/200
# 10/10 [==============================] - 8s 738ms/step - loss: 0.0273 - accuracy: 0.9940 - val_loss: 0.0255 - val_accuracy: 0.9897
# Epoch 12/200
# 10/10 [==============================] - 8s 772ms/step - loss: 0.0221 - accuracy: 0.9940 - val_loss: 0.0238 - val_accuracy: 0.9897
# Epoch 13/200
# 10/10 [==============================] - 9s 841ms/step - loss: 0.0347 - accuracy: 0.9897 - val_loss: 0.0218 - val_accuracy: 0.9897
# Epoch 14/200
# 10/10 [==============================] - 9s 800ms/step - loss: 0.0222 - accuracy: 0.9922 - val_loss: 0.0212 - val_accuracy: 0.9897
# Epoch 15/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0179 - accuracy: 0.9948 - val_loss: 0.0225 - val_accuracy: 0.9897
# Epoch 16/200
# 10/10 [==============================] - 8s 747ms/step - loss: 0.0172 - accuracy: 0.9957 - val_loss: 0.0217 - val_accuracy: 0.9897
# Epoch 17/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0321 - accuracy: 0.9888 - val_loss: 0.0226 - val_accuracy: 0.9897
# Epoch 18/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0190 - accuracy: 0.9940 - val_loss: 0.0244 - val_accuracy: 0.9897
# Epoch 19/200
# 10/10 [==============================] - 7s 734ms/step - loss: 0.0346 - accuracy: 0.9897 - val_loss: 0.0248 - val_accuracy: 0.9897
# Epoch 20/200
# 10/10 [==============================] - 7s 741ms/step - loss: 0.0318 - accuracy: 0.9922 - val_loss: 0.0244 - val_accuracy: 0.9897
# Epoch 21/200
# 10/10 [==============================] - 8s 743ms/step - loss: 0.0208 - accuracy: 0.9914 - val_loss: 0.0216 - val_accuracy: 0.9897
# Epoch 22/200
# 10/10 [==============================] - 8s 822ms/step - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.0206 - val_accuracy: 0.9931
# Epoch 23/200
# 10/10 [==============================] - 8s 745ms/step - loss: 0.0262 - accuracy: 0.9905 - val_loss: 0.0193 - val_accuracy: 0.9931
# Epoch 24/200
# 10/10 [==============================] - 8s 739ms/step - loss: 0.0204 - accuracy: 0.9922 - val_loss: 0.0184 - val_accuracy: 0.9931
# Epoch 25/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0209 - accuracy: 0.9914 - val_loss: 0.0173 - val_accuracy: 0.9931
# Epoch 26/200
# 10/10 [==============================] - 7s 738ms/step - loss: 0.0317 - accuracy: 0.9897 - val_loss: 0.0166 - val_accuracy: 0.9931
# Epoch 27/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0248 - accuracy: 0.9862 - val_loss: 0.0166 - val_accuracy: 0.9966
# Epoch 28/200
# 10/10 [==============================] - 8s 747ms/step - loss: 0.0223 - accuracy: 0.9905 - val_loss: 0.0168 - val_accuracy: 0.9966
# Epoch 29/200
# 10/10 [==============================] - 7s 743ms/step - loss: 0.0215 - accuracy: 0.9940 - val_loss: 0.0171 - val_accuracy: 0.9931
# Epoch 30/200
# 10/10 [==============================] - 7s 815ms/step - loss: 0.0165 - accuracy: 0.9966 - val_loss: 0.0181 - val_accuracy: 0.9931
# Epoch 31/200
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0215 - accuracy: 0.9940 - val_loss: 0.0189 - val_accuracy: 0.9897
# Epoch 32/200
# 10/10 [==============================] - 8s 739ms/step - loss: 0.0184 - accuracy: 0.9922 - val_loss: 0.0192 - val_accuracy: 0.9897
# Epoch 33/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0146 - accuracy: 0.9931 - val_loss: 0.0203 - val_accuracy: 0.9897
# Epoch 34/200
# 10/10 [==============================] - 7s 819ms/step - loss: 0.0189 - accuracy: 0.9940 - val_loss: 0.0273 - val_accuracy: 0.9897
# Epoch 35/200
# 10/10 [==============================] - 8s 745ms/step - loss: 0.0301 - accuracy: 0.9914 - val_loss: 0.0276 - val_accuracy: 0.9897
# Epoch 36/200
# 10/10 [==============================] - 8s 739ms/step - loss: 0.0312 - accuracy: 0.9905 - val_loss: 0.0269 - val_accuracy: 0.9897
# Epoch 37/200
# 10/10 [==============================] - 7s 740ms/step - loss: 0.0426 - accuracy: 0.9862 - val_loss: 0.0265 - val_accuracy: 0.9897
# Epoch 38/200
# 10/10 [==============================] - 8s 747ms/step - loss: 0.0195 - accuracy: 0.9957 - val_loss: 0.0263 - val_accuracy: 0.9897
# Epoch 39/200
# 10/10 [==============================] - 8s 746ms/step - loss: 0.0246 - accuracy: 0.9940 - val_loss: 0.0237 - val_accuracy: 0.9897
# Epoch 40/200
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0229 - accuracy: 0.9940 - val_loss: 0.0212 - val_accuracy: 0.9897
# Epoch 41/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0144 - accuracy: 0.9966 - val_loss: 0.0214 - val_accuracy: 0.9897
# Epoch 42/200
# 10/10 [==============================] - 8s 748ms/step - loss: 0.0164 - accuracy: 0.9931 - val_loss: 0.0221 - val_accuracy: 0.9897
# Epoch 43/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0122 - accuracy: 0.9974 - val_loss: 0.0218 - val_accuracy: 0.9897
# Epoch 44/200
# 10/10 [==============================] - 8s 748ms/step - loss: 0.0267 - accuracy: 0.9905 - val_loss: 0.0206 - val_accuracy: 0.9897
# Epoch 45/200
# 10/10 [==============================] - 9s 950ms/step - loss: 0.0151 - accuracy: 0.9948 - val_loss: 0.0208 - val_accuracy: 0.9897
# Epoch 46/200
# 10/10 [==============================] - 8s 746ms/step - loss: 0.0194 - accuracy: 0.9914 - val_loss: 0.0192 - val_accuracy: 0.9897
# Epoch 47/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0162 - accuracy: 0.9940 - val_loss: 0.0174 - val_accuracy: 0.9931
# Epoch 48/200
# 10/10 [==============================] - 7s 733ms/step - loss: 0.0186 - accuracy: 0.9948 - val_loss: 0.0162 - val_accuracy: 0.9931
# Epoch 49/200
# 10/10 [==============================] - 8s 747ms/step - loss: 0.0227 - accuracy: 0.9931 - val_loss: 0.0156 - val_accuracy: 0.9931
# Epoch 50/200
# 10/10 [==============================] - 8s 740ms/step - loss: 0.0277 - accuracy: 0.9879 - val_loss: 0.0171 - val_accuracy: 0.9931
# Epoch 51/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0205 - accuracy: 0.9957 - val_loss: 0.0188 - val_accuracy: 0.9931
# Epoch 52/200
# 10/10 [==============================] - 8s 746ms/step - loss: 0.0284 - accuracy: 0.9879 - val_loss: 0.0395 - val_accuracy: 0.9794
# Epoch 53/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0280 - accuracy: 0.9905 - val_loss: 0.0407 - val_accuracy: 0.9794
# Epoch 54/200
# 10/10 [==============================] - 7s 730ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 0.0348 - val_accuracy: 0.9863
# Epoch 55/200
# 10/10 [==============================] - 7s 736ms/step - loss: 0.0161 - accuracy: 0.9922 - val_loss: 0.0293 - val_accuracy: 0.9897
# Epoch 56/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0177 - accuracy: 0.9922 - val_loss: 0.0242 - val_accuracy: 0.9931
# Epoch 57/200
# 10/10 [==============================] - 7s 733ms/step - loss: 0.0227 - accuracy: 0.9931 - val_loss: 0.0233 - val_accuracy: 0.9931
# Epoch 58/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0122 - accuracy: 0.9983 - val_loss: 0.0250 - val_accuracy: 0.9897
# Epoch 59/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0156 - accuracy: 0.9922 - val_loss: 0.0242 - val_accuracy: 0.9897
# Epoch 60/200
# 10/10 [==============================] - 7s 736ms/step - loss: 0.0131 - accuracy: 0.9948 - val_loss: 0.0205 - val_accuracy: 0.9931
# Epoch 61/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0221 - accuracy: 0.9922 - val_loss: 0.0212 - val_accuracy: 0.9931
# Epoch 62/200
# 10/10 [==============================] - 8s 739ms/step - loss: 0.0221 - accuracy: 0.9931 - val_loss: 0.0211 - val_accuracy: 0.9931
# Epoch 63/200
# 10/10 [==============================] - 8s 743ms/step - loss: 0.0173 - accuracy: 0.9940 - val_loss: 0.0193 - val_accuracy: 0.9931
# Epoch 64/200
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0145 - accuracy: 0.9948 - val_loss: 0.0170 - val_accuracy: 0.9931
# Epoch 65/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0129 - accuracy: 0.9948 - val_loss: 0.0159 - val_accuracy: 0.9931
# Epoch 66/200
# 10/10 [==============================] - 8s 825ms/step - loss: 0.0144 - accuracy: 0.9948 - val_loss: 0.0173 - val_accuracy: 0.9931
# Epoch 67/200
# 10/10 [==============================] - 7s 734ms/step - loss: 0.0245 - accuracy: 0.9948 - val_loss: 0.0185 - val_accuracy: 0.9931
# Epoch 68/200
# 10/10 [==============================] - 7s 730ms/step - loss: 0.0289 - accuracy: 0.9905 - val_loss: 0.0343 - val_accuracy: 0.9863
# Epoch 69/200
# 10/10 [==============================] - 8s 740ms/step - loss: 0.0538 - accuracy: 0.9871 - val_loss: 0.0686 - val_accuracy: 0.9794
# Epoch 70/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0514 - accuracy: 0.9879 - val_loss: 0.0773 - val_accuracy: 0.9656
# Epoch 71/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0365 - accuracy: 0.9871 - val_loss: 0.1288 - val_accuracy: 0.9553
# Epoch 72/200
# 10/10 [==============================] - 7s 740ms/step - loss: 0.0270 - accuracy: 0.9905 - val_loss: 0.0930 - val_accuracy: 0.9553
# Epoch 73/200
# 10/10 [==============================] - 8s 826ms/step - loss: 0.0251 - accuracy: 0.9888 - val_loss: 0.0578 - val_accuracy: 0.9691
# Epoch 74/200
# 10/10 [==============================] - 7s 734ms/step - loss: 0.0260 - accuracy: 0.9922 - val_loss: 0.0364 - val_accuracy: 0.9863
# Epoch 75/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0191 - accuracy: 0.9957 - val_loss: 0.0263 - val_accuracy: 0.9931
# Epoch 76/200
# 10/10 [==============================] - 8s 747ms/step - loss: 0.0148 - accuracy: 0.9940 - val_loss: 0.0202 - val_accuracy: 0.9931
# Epoch 77/200
# 10/10 [==============================] - 9s 918ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.0187 - val_accuracy: 0.9931
# Epoch 78/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.0150 - val_accuracy: 0.9931
# Epoch 79/200
# 10/10 [==============================] - 8s 748ms/step - loss: 0.0257 - accuracy: 0.9897 - val_loss: 0.0141 - val_accuracy: 0.9931
# Epoch 80/200
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0235 - accuracy: 0.9922 - val_loss: 0.0120 - val_accuracy: 0.9931
# Epoch 81/200
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0222 - accuracy: 0.9948 - val_loss: 0.0109 - val_accuracy: 0.9931
# Epoch 82/200
# 10/10 [==============================] - 8s 737ms/step - loss: 0.0213 - accuracy: 0.9931 - val_loss: 0.0162 - val_accuracy: 0.9931
# Epoch 83/200
# 10/10 [==============================] - 7s 736ms/step - loss: 0.0223 - accuracy: 0.9922 - val_loss: 0.0156 - val_accuracy: 0.9931
# Epoch 84/200
# 10/10 [==============================] - 7s 736ms/step - loss: 0.0141 - accuracy: 0.9931 - val_loss: 0.0150 - val_accuracy: 0.9931
# Epoch 85/200
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0116 - accuracy: 0.9940 - val_loss: 0.0164 - val_accuracy: 0.9931
# Epoch 86/200
# 10/10 [==============================] - 8s 747ms/step - loss: 0.0134 - accuracy: 0.9957 - val_loss: 0.0168 - val_accuracy: 0.9931
# Epoch 87/200
# 10/10 [==============================] - 7s 734ms/step - loss: 0.0173 - accuracy: 0.9948 - val_loss: 0.0122 - val_accuracy: 0.9931
# Epoch 88/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0223 - accuracy: 0.9940 - val_loss: 0.0129 - val_accuracy: 0.9931
# Epoch 89/200
# 10/10 [==============================] - 8s 739ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0127 - val_accuracy: 0.9931
# Epoch 90/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 0.0095 - val_accuracy: 0.9966
# Epoch 91/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0150 - accuracy: 0.9966 - val_loss: 0.0093 - val_accuracy: 0.9931
# Epoch 92/200
# 10/10 [==============================] - 8s 746ms/step - loss: 0.0142 - accuracy: 0.9983 - val_loss: 0.0093 - val_accuracy: 0.9931
# Epoch 93/200
# 10/10 [==============================] - 7s 738ms/step - loss: 0.0151 - accuracy: 0.9966 - val_loss: 0.0105 - val_accuracy: 0.9931
# Epoch 94/200
# 10/10 [==============================] - 7s 740ms/step - loss: 0.0121 - accuracy: 0.9966 - val_loss: 0.0095 - val_accuracy: 0.9966
# Epoch 95/200
# 10/10 [==============================] - 8s 740ms/step - loss: 0.0173 - accuracy: 0.9931 - val_loss: 0.0096 - val_accuracy: 0.9931
# Epoch 96/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0111 - val_accuracy: 0.9931
# Epoch 97/200
# 10/10 [==============================] - 8s 748ms/step - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.0137 - val_accuracy: 0.9931
# Epoch 98/200
# 10/10 [==============================] - 8s 745ms/step - loss: 0.0089 - accuracy: 0.9966 - val_loss: 0.0144 - val_accuracy: 0.9931
# Epoch 99/200
# 10/10 [==============================] - 8s 751ms/step - loss: 0.0166 - accuracy: 0.9922 - val_loss: 0.0141 - val_accuracy: 0.9931
# Epoch 100/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0079 - accuracy: 0.9983 - val_loss: 0.0115 - val_accuracy: 0.9931
# Epoch 101/200
# 10/10 [==============================] - 7s 816ms/step - loss: 0.0183 - accuracy: 0.9931 - val_loss: 0.0075 - val_accuracy: 0.9931
# Epoch 102/200
# 10/10 [==============================] - 8s 740ms/step - loss: 0.0112 - accuracy: 0.9957 - val_loss: 0.0081 - val_accuracy: 0.9931
# Epoch 103/200
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9931
# Epoch 104/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0089 - accuracy: 0.9966 - val_loss: 0.0092 - val_accuracy: 0.9931
# Epoch 105/200
# 10/10 [==============================] - 7s 740ms/step - loss: 0.0055 - accuracy: 0.9974 - val_loss: 0.0076 - val_accuracy: 0.9931
# Epoch 106/200
# 10/10 [==============================] - 8s 738ms/step - loss: 0.0101 - accuracy: 0.9974 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 8s 826ms/step - loss: 0.0087 - accuracy: 0.9991 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 9s 783ms/step - loss: 0.0159 - accuracy: 0.9966 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 8s 823ms/step - loss: 0.0100 - accuracy: 0.9948 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 8s 820ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0084 - val_accuracy: 0.9931
# Epoch 111/200
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0160 - accuracy: 0.9940 - val_loss: 0.0120 - val_accuracy: 0.9931
# Epoch 112/200
# 10/10 [==============================] - 8s 743ms/step - loss: 0.0117 - accuracy: 0.9940 - val_loss: 0.0121 - val_accuracy: 0.9931
# Epoch 113/200
# 10/10 [==============================] - 8s 747ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9897
# Epoch 114/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0101 - accuracy: 0.9983 - val_loss: 0.0197 - val_accuracy: 0.9931
# Epoch 115/200
# 10/10 [==============================] - 8s 750ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 0.0299 - val_accuracy: 0.9931
# Epoch 116/200
# 10/10 [==============================] - 8s 738ms/step - loss: 0.0224 - accuracy: 0.9957 - val_loss: 0.0306 - val_accuracy: 0.9931
# Epoch 117/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0165 - accuracy: 0.9966 - val_loss: 0.0215 - val_accuracy: 0.9931
# Epoch 118/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0492 - accuracy: 0.9862 - val_loss: 0.0132 - val_accuracy: 0.9897
# Epoch 119/200
# 10/10 [==============================] - 8s 750ms/step - loss: 0.0182 - accuracy: 0.9948 - val_loss: 0.0204 - val_accuracy: 0.9897
# Epoch 120/200
# 10/10 [==============================] - 7s 740ms/step - loss: 0.0055 - accuracy: 0.9991 - val_loss: 0.0156 - val_accuracy: 0.9931
# Epoch 121/200
# 10/10 [==============================] - 7s 815ms/step - loss: 0.0218 - accuracy: 0.9940 - val_loss: 0.0158 - val_accuracy: 0.9931
# Epoch 122/200
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0132 - accuracy: 0.9966 - val_loss: 0.0129 - val_accuracy: 0.9931
# Epoch 123/200
# 10/10 [==============================] - 7s 742ms/step - loss: 0.0239 - accuracy: 0.9931 - val_loss: 0.0084 - val_accuracy: 0.9931
# Epoch 124/200
# 10/10 [==============================] - 8s 746ms/step - loss: 0.0122 - accuracy: 0.9940 - val_loss: 0.0084 - val_accuracy: 0.9931
# Epoch 125/200
# 10/10 [==============================] - 8s 751ms/step - loss: 0.0214 - accuracy: 0.9922 - val_loss: 0.0094 - val_accuracy: 0.9931
# Epoch 126/200
# 10/10 [==============================] - 8s 743ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.0115 - val_accuracy: 0.9897
# Epoch 127/200
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.0126 - val_accuracy: 0.9897
# Epoch 128/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0185 - accuracy: 0.9931 - val_loss: 0.0155 - val_accuracy: 0.9897
# Epoch 129/200
# 10/10 [==============================] - 7s 734ms/step - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.0154 - val_accuracy: 0.9897
# Epoch 130/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0131 - accuracy: 0.9931 - val_loss: 0.0096 - val_accuracy: 0.9897
# Epoch 131/200
# 10/10 [==============================] - 8s 824ms/step - loss: 0.0251 - accuracy: 0.9948 - val_loss: 0.0080 - val_accuracy: 0.9966
# Epoch 132/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0129 - accuracy: 0.9974 - val_loss: 0.0111 - val_accuracy: 0.9966
# Epoch 133/200
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0177 - accuracy: 0.9948 - val_loss: 0.0113 - val_accuracy: 0.9966
# Epoch 134/200
# 10/10 [==============================] - 7s 734ms/step - loss: 0.0212 - accuracy: 0.9922 - val_loss: 0.0131 - val_accuracy: 0.9931
# Epoch 135/200
# 10/10 [==============================] - 8s 820ms/step - loss: 0.0232 - accuracy: 0.9931 - val_loss: 0.0092 - val_accuracy: 0.9966
# Epoch 136/200
# 10/10 [==============================] - 7s 820ms/step - loss: 0.0185 - accuracy: 0.9948 - val_loss: 0.0060 - val_accuracy: 0.9966
# Epoch 137/200
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0110 - accuracy: 0.9957 - val_loss: 0.0072 - val_accuracy: 0.9966
# Epoch 138/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0076 - accuracy: 0.9983 - val_loss: 0.0083 - val_accuracy: 0.9966
# Epoch 139/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.0078 - val_accuracy: 0.9966
# Epoch 140/200
# 10/10 [==============================] - 8s 740ms/step - loss: 0.0098 - accuracy: 0.9974 - val_loss: 0.0075 - val_accuracy: 0.9966
# Epoch 141/200
# 10/10 [==============================] - 9s 815ms/step - loss: 0.0143 - accuracy: 0.9948 - val_loss: 0.0113 - val_accuracy: 0.9966
# Epoch 142/200
# 10/10 [==============================] - 8s 746ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9966
# Epoch 143/200
# 10/10 [==============================] - 8s 738ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0115 - val_accuracy: 0.9966
# Epoch 144/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.0114 - val_accuracy: 0.9966
# Epoch 145/200
# 10/10 [==============================] - 8s 828ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0113 - val_accuracy: 0.9966
# Epoch 146/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0089 - accuracy: 0.9966 - val_loss: 0.0109 - val_accuracy: 0.9966
# Epoch 147/200
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.0107 - val_accuracy: 0.9966
# Epoch 148/200
# 10/10 [==============================] - 7s 732ms/step - loss: 0.0119 - accuracy: 0.9974 - val_loss: 0.0109 - val_accuracy: 0.9931
# Epoch 149/200
# 10/10 [==============================] - 8s 740ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 0.0041 - val_accuracy: 0.9966
# Epoch 151/200
# 10/10 [==============================] - 8s 823ms/step - loss: 0.0309 - accuracy: 0.9888 - val_loss: 0.0051 - val_accuracy: 0.9966
# Epoch 152/200
# 10/10 [==============================] - 8s 739ms/step - loss: 0.0200 - accuracy: 0.9940 - val_loss: 0.0065 - val_accuracy: 0.9966
# Epoch 153/200
# 10/10 [==============================] - 8s 746ms/step - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.0064 - val_accuracy: 0.9966
# Epoch 154/200
# 10/10 [==============================] - 8s 747ms/step - loss: 0.0128 - accuracy: 0.9974 - val_loss: 0.0062 - val_accuracy: 0.9966
# Epoch 155/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0074 - accuracy: 0.9991 - val_loss: 0.0058 - val_accuracy: 0.9966
# Epoch 156/200
# 10/10 [==============================] - 7s 736ms/step - loss: 0.0088 - accuracy: 0.9966 - val_loss: 0.0055 - val_accuracy: 0.9966
# Epoch 157/200
# 10/10 [==============================] - 8s 826ms/step - loss: 0.0125 - accuracy: 0.9983 - val_loss: 0.0051 - val_accuracy: 0.9966
# Epoch 158/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0076 - accuracy: 0.9983 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.0089 - val_accuracy: 0.9931
# Epoch 160/200
# 10/10 [==============================] - 8s 743ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 0.0115 - val_accuracy: 0.9897
# Epoch 161/200
# 10/10 [==============================] - 8s 753ms/step - loss: 0.0098 - accuracy: 0.9957 - val_loss: 0.0120 - val_accuracy: 0.9897
# Epoch 162/200
# 10/10 [==============================] - 8s 743ms/step - loss: 0.0135 - accuracy: 0.9940 - val_loss: 0.0121 - val_accuracy: 0.9897
# Epoch 163/200
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9897
# Epoch 164/200
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9897
# Epoch 165/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0104 - val_accuracy: 0.9931
# Epoch 166/200
# 10/10 [==============================] - 8s 739ms/step - loss: 0.0121 - accuracy: 0.9948 - val_loss: 0.0113 - val_accuracy: 0.9897
# Epoch 167/200
# 10/10 [==============================] - 8s 740ms/step - loss: 0.0113 - accuracy: 0.9966 - val_loss: 0.0121 - val_accuracy: 0.9897
# Epoch 168/200
# 10/10 [==============================] - 8s 751ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0111 - val_accuracy: 0.9931
# Epoch 169/200
# 10/10 [==============================] - 8s 746ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0118 - val_accuracy: 0.9897
# Epoch 170/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.0126 - val_accuracy: 0.9931
# Epoch 171/200
# 10/10 [==============================] - 9s 960ms/step - loss: 0.0107 - accuracy: 0.9974 - val_loss: 0.0149 - val_accuracy: 0.9931
# Epoch 172/200
# 10/10 [==============================] - 8s 743ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0167 - val_accuracy: 0.9931
# Epoch 173/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0083 - accuracy: 0.9983 - val_loss: 0.0161 - val_accuracy: 0.9931
# Epoch 174/200
# 10/10 [==============================] - 7s 738ms/step - loss: 0.0155 - accuracy: 0.9940 - val_loss: 0.0147 - val_accuracy: 0.9897
# Epoch 175/200
# 10/10 [==============================] - 7s 736ms/step - loss: 0.0179 - accuracy: 0.9974 - val_loss: 0.0182 - val_accuracy: 0.9897
# Epoch 176/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0099 - accuracy: 0.9991 - val_loss: 0.0238 - val_accuracy: 0.9897
# Epoch 177/200
# 10/10 [==============================] - 8s 824ms/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.0222 - val_accuracy: 0.9897
# Epoch 178/200
# 10/10 [==============================] - 7s 821ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0187 - val_accuracy: 0.9897
# Epoch 179/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0161 - accuracy: 0.9966 - val_loss: 0.0197 - val_accuracy: 0.9931
# Epoch 180/200
# 10/10 [==============================] - 8s 743ms/step - loss: 0.0103 - accuracy: 0.9957 - val_loss: 0.0272 - val_accuracy: 0.9931
# Epoch 181/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.0257 - val_accuracy: 0.9931
# Epoch 182/200
# 10/10 [==============================] - 8s 747ms/step - loss: 0.0097 - accuracy: 0.9957 - val_loss: 0.0292 - val_accuracy: 0.9897
# Epoch 183/200
# 10/10 [==============================] - 8s 823ms/step - loss: 0.0122 - accuracy: 0.9931 - val_loss: 0.0274 - val_accuracy: 0.9931
# Epoch 184/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0118 - accuracy: 0.9957 - val_loss: 0.0192 - val_accuracy: 0.9931
# Epoch 185/200
# 10/10 [==============================] - 8s 741ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.0167 - val_accuracy: 0.9931
# Epoch 186/200
# 10/10 [==============================] - 8s 738ms/step - loss: 0.0078 - accuracy: 0.9966 - val_loss: 0.0178 - val_accuracy: 0.9931
# Epoch 187/200
# 10/10 [==============================] - 8s 740ms/step - loss: 0.0087 - accuracy: 0.9966 - val_loss: 0.0175 - val_accuracy: 0.9931
# Epoch 188/200
# 10/10 [==============================] - 8s 745ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0153 - val_accuracy: 0.9931
# Epoch 189/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0067 - accuracy: 0.9974 - val_loss: 0.0166 - val_accuracy: 0.9931
# Epoch 190/200
# 10/10 [==============================] - 8s 742ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0166 - val_accuracy: 0.9931
# Epoch 191/200
# 10/10 [==============================] - 7s 740ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0156 - val_accuracy: 0.9966
# Epoch 192/200
# 10/10 [==============================] - 8s 827ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.0154 - val_accuracy: 0.9931
# Epoch 193/200
# 10/10 [==============================] - 8s 740ms/step - loss: 0.0049 - accuracy: 0.9974 - val_loss: 0.0180 - val_accuracy: 0.9897
# Epoch 194/200
# 10/10 [==============================] - 8s 743ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0198 - val_accuracy: 0.9897
# Epoch 195/200
# 10/10 [==============================] - 7s 740ms/step - loss: 0.0040 - accuracy: 0.9974 - val_loss: 0.0188 - val_accuracy: 0.9931
# Epoch 196/200
# 10/10 [==============================] - 8s 824ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.0149 - val_accuracy: 0.9931
# Epoch 197/200
# 10/10 [==============================] - 7s 738ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9931
# Epoch 198/200
# 10/10 [==============================] - 8s 744ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0143 - val_accuracy: 0.9931
# Epoch 199/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0145 - val_accuracy: 0.9931
# Epoch 200/200
# 10/10 [==============================] - 7s 735ms/step - loss: 0.0059 - accuracy: 0.9974 - val_loss: 0.0165 - val_accuracy: 0.9931

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
pred = model.evaluate(X_test, Y_test)
print(f'Test Set Accuracy: {pred[1]}')
print(f'Test Set Loss: {pred[0]}')
# Out:
# 10/10 [==============================] - 0s 39ms/step - loss: 0.0165 - accuracy: 0.9931
# Test Set Accuracy: 0.993127167224884
# Test Set Loss: 0.016539227217435837

# %%
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
Y_test_pred = np.argmax(Y_test, axis=1)
print(classification_report(Y_test_pred, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       142
#            1       0.99      0.99      0.99       149
#
#     accuracy                           0.99       291
#    macro avg       0.99      0.99      0.99       291
# weighted avg       0.99      0.99      0.99       291

# %%
model.save('/content/drive/MyDrive/driver_drowsiness_detection/Driver_Drowsiness_Detection_new.h5')
